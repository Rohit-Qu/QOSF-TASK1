# %% [markdown]
# # RESULTS

# %% [markdown]
# Following cells are the list of costs per number of layer

# %%
ada_ry_rx = [0.49827631205955836,0.30568902934442344,0.21156695163880637,0.09141338274804395,
             0.030854414013858474,0.023658947597585307,0.0038013775623197943,0.0026405077287385325,
             0.0022941727358758044]

# %%
gd = [0.5043786353560482,0.15482363224263082,0.05116050481038599,0.017022486332141006,
      0.020575831089564775,0.006707340335315776,0.01741225949133245,0.0142017787522113,
      0.00881338251813404]

# %%
gd1 = [0.4935228258184716,0.26470049460985623,0.0863381542981734,0.024764531109131703,
      0.012027288905068084,0.018259751762320066,0.007841036414991436,0.016983218595960234,
      0.014642796338934241]

# %%
#Plotting cost vs iteration 

s = [1,2,3,4,5,6,7,8,9]

from matplotlib import pyplot as plt

plt.style.use("seaborn")
plt.plot(s,ada_ry_rx ,"b", label="AdagradOptimizer descent- modified circuit")
plt.plot(s,gd1 ,"g", label="gradient descent")
plt.plot(s,gd ,"r", label="gradient descent modified circuit")

plt.ylabel("Cost function value")
plt.xlabel("Optimization steps")
plt.title('Result')
plt.legend()
plt.show()

# %% [markdown]
# In the modified circuit all the RX gates has been rplaced by RY gates while RZ by RX. Following conclusion can be drawn from the plot above:-
#
# 1.) For lesser number of layers the modified version of the circuit gives less error and can be preffered over the given circuit in the task.
#
# 2.) Also , the optimizer gradient descent seems to be a better option for the task.
#
# 3.) For larger number of layers the optimizer does'nt seem to give much advanage rather the curve above seems to be saturating starting from number of layers=5
